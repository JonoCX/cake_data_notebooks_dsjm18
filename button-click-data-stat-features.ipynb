# %% [markdown]
# # Button Click Data
# This is the step by step method of preprocesssing, transforming, and building a model for the CAKE button click data. The steps have to be the same as the low level interaction data.

# %%
import pandas as pd
import numpy as np

# %%
df_test = pd.read_csv('./data/test-interactions_results.csv')
df_live = pd.read_csv('./data/live-interactions_statistics_results.csv')

# %% [markdown]
# On reflection, this seems like a silly metric -- it's the same as the total length of the session. We also don't need the most frequent item and action pair, while we could do some NLP on this, it's beyond the scope of this (and wasn't done with the low-level data)

# %%
df_test.drop(['totalTimeBetweenClicks', 'mostFrequentItemAction'], inplace=True, axis=1)
df_live.drop(['totalTimeBetweenClicks', 'mostFrequentItemAction'], inplace=True, axis=1)

# %% [markdown]
# ### Preprocess the data

# %% [markdown]
# First, let's remove those users that experienced technical difficulties during the live study

# %%
technical_difficulties_pid = ["109", "112", "113", "121", "217", "220", "205", "401", "407", "425"]
del_index = []

def remove_technical_difficulties(row):
    pid = row['userid']
    if pid in technical_difficulties_pid:
        return del_index.append(row.name)
    
# apply the function to remove the pids
df_live.apply(remove_technical_difficulties, axis=1)
df_live.drop(del_index, inplace=True)
df_live.head()
# Out:
#    userid  sessionNo  totalEvents  totalTime  meanTimeBetweenClicks  \
# 0     310          1           13        181              13.923077
# 1     310          2            2        449             224.500000
# 2     310          3           59       2794              47.355932
# 3     206          1            2         34              17.000000
# 4     206          2           77        287               3.727273
#
#    stdTimeBetweenClicks  meanClicksPerSecond  stdClicksPerSecond  \
# 0             15.359370             1.083333            0.288675
# 1            317.490945             1.000000            0.000000
# 2             87.028684             1.180000            0.437526
# 3             24.041631             1.000000            0.000000
# 4              6.229464             1.509804            0.880285
#
#    meanClicksPerMinute  stdClicksPerMinute
# 0             3.250000            1.500000
# 1             1.000000            0.000000
# 2             2.360000            2.413158
# 3             1.000000            0.000000
# 4            12.833333           15.223885

# %% [markdown]
# Now that we've done that, we need add our labels to the features.

# %%
df_live['label'] = 0
df_test['label'] = 1

# %% [markdown]
# Okay, let's split the participants that have multiple sessions off from the main live dataframe.

# %%
df_live_multi = df_live[df_live.groupby('userid').userid.transform(len) > 1]
df_live_single = df_live.loc[~df_live.duplicated(subset='userid', keep=False), :]

# %% [markdown]
# ### Transform the Data

# %% [markdown]
# We need to create our X (feature set) and y (labels).

# %%
features = pd.concat([df_live_single, df_test], ignore_index=True)
true_y = features['label']
true_X = features.loc[:, 'meanClicksPerMinute':'totalTime']
test_X = df_live_multi.loc[:, 'totalEvents':'stdClicksPerMinute']

# %% [markdown]
# Let's reorder the columns (it should matter but it still bothers me).

# %%
true_X = true_X.reindex(test_X.columns, axis=1)

# %% [markdown]
# Let's now scale the data!

# %%
from sklearn.preprocessing import StandardScaler
scaled_X = pd.DataFrame(StandardScaler().fit_transform(true_X), columns=true_X.columns)
scaled_test_X = pd.DataFrame(StandardScaler().fit_transform(test_X), columns=test_X.columns)

# %% [markdown]
# ### Classification

# %%
from sklearn.svm import SVC
svm = SVC() # out of the box classifier
svm.fit(scaled_X, true_y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# Prediction!

# %%
test_X['predicition'] = svm.predict(scaled_test_X)
test_X
# Out:
#      totalEvents  totalTime  meanTimeBetweenClicks  stdTimeBetweenClicks  \
# 0             13        181              13.923077             15.359370
# 1              2        449             224.500000            317.490945
# 2             59       2794              47.355932             87.028684
# 3              2         34              17.000000             24.041631
# 4             77        287               3.727273              6.229464
# 5            112       2776              24.785714             36.817159
# 6              7        175              25.000000             30.697448
# 7             45       1782              39.600000             37.250015
# 12             3         52              17.333333             21.221059
# 13            23        212               9.217391             13.218295
# 16            10        150              15.000000             29.017236
# 17             4          0               0.000000              0.000000
# 18            73       2453              33.602740             70.321630
# 19            10        563              56.300000            112.385300
# 20           177       1096               6.192090             53.463851
# 21             4        150              37.500000             72.344085
# 22             2          1               0.500000              0.707107
# 23             8       1796             224.500000            576.730192
# 24             2          3               1.500000              2.121320
# 25            36       4324             120.111111            295.875435
# 33            51       1204              23.607843             45.690296
# 34            58       2935              50.603448             49.614281
# 35             6         78              13.000000             15.440207
# 36            71       3866              54.450704             81.405298
# 37            22        213               9.681818             20.737329
# 40             1          0               0.000000              0.000000
# 41            50       3553              71.060000            117.268471
# 45            11        377              34.272727             37.261484
# 46            12        908              75.666667            150.812547
# 47             8       2653             331.625000            476.753886
# 48             1          0               0.000000              0.000000
# 49            35       4424             126.400000            214.493411
# 50             3         13               4.333333              5.131601
# 51             3         67              22.333333             22.007574
# 52            52       2086              40.115385             64.789146
# 55            50       2976              59.520000             82.546768
# 56            16        193              12.062500             18.112496
# 62             2        307             153.500000            217.081782
# 63            77       3540              45.974026             79.604280
# 65            35        415              11.857143             19.925070
# 66            53       3870              73.018868            102.764011
# 67            64       1412              22.062500             31.693911
# 68            28        123               4.392857              3.909526
# 70            47       2654              56.468085             66.342934
# 71            12        454              37.833333             66.814306
# 77             5       1227             245.400000            328.309001
# 78             3          4               1.333333              1.154701
# 79            24        237               9.875000             18.817920
# 80            76       2564              33.736842             51.513459
# 82            43       2001              46.534884             79.393639
# 83             4        168              42.000000             80.684571
# 85             2         65              32.500000             45.961941
# 86             1          0               0.000000              0.000000
# 87             3       1256             418.666667            724.286085
# 88            42       2552              60.761905             66.704594
# 100          246       2913              11.841463             28.124854
# 101            2          7               3.500000              4.949747
# 112           68       3113              45.779412            102.041380
# 113            2          0               0.000000              0.000000
#
#      meanClicksPerSecond  stdClicksPerSecond  meanClicksPerMinute  \
# 0               1.083333            0.288675             3.250000
# 1               1.000000            0.000000             1.000000
# 2               1.180000            0.437526             2.360000
# 3               1.000000            0.000000             1.000000
# 4               1.509804            0.880285            12.833333
# 5               1.000000            0.000000             3.111111
# 6               1.000000            0.000000             1.750000
# 7               1.000000            0.000000             1.800000
# 12              1.000000            0.000000             3.000000
# 13              1.045455            0.213201             5.750000
# 16              1.111111            0.333333             3.333333
# 17              4.000000            0.000000             4.000000
# 18              1.825000            1.034966             4.562500
# 19              1.111111            0.333333             3.333333
# 20              4.538462            2.490468            35.400000
